# %%
s1 = set([1,2,3])  #ctrl+/ 누르면 선택 셀 주석달기 가능
s1
# Out:
# {1, 2, 3}

# %%
s2 = set('Hello') #중복허용x,순서가 존재x
s2
# Out:
# {'H', 'e', 'l', 'o'}

# %%
s = set()

# %%
s
# Out:
# set()

# %%
s1 = set([1,2,3])
l1 = list(s1)
l1
# Out:
# [1, 2, 3]

# %%
l1[0]
# Out:
# 1

# %%
t1 = tuple(s1)

# %%
t1
# Out:
# (1, 2, 3)

# %%
t1[0]
# Out:
# 1

# %%
s1 = set([1,2,3,4,5,6])
s2 = set([4,5,6,7,8,9])
s1 & s2 #&동시만족(교집합)
# Out:
# {4, 5, 6}

# %%
s1.intersection(s2)
# Out:
# {4, 5, 6}

# %%
s1| s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s1 - s2
# Out:
# {1, 2, 3}

# %%
s2 - s1
# Out:
# {7, 8, 9}

# %%
s1.difference(s2)
# Out:
# {1, 2, 3}

# %%
s2.difference(s1)
# Out:
# {7, 8, 9}

# %%
s1 = set([1,2,3])
s1.add(4)
s1
# Out:
# {1, 2, 3, 4}

# %%
s1 = set([1,2,3])
s1.update([4,5,6])
s1
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1 = set([1,2,3])
s1.remove(2)
s1
# Out:
# {1, 3}

# %%
##############################################
#bool 불 자료형

# %%
a = True
b = False

# %%
type(a)  #type 무슨 자료형인지 알려주는 함수
# Out:
# bool

# %%
type(b)
# Out:
# bool

# %%
1 == 1
# Out:
# True

# %%
2 > 1
# Out:
# True

# %%
2 < 1
# Out:
# False

# %%
'Python'
# Out:
# 'Python'

# %%
''
# Out:
# ''

# %%
a = [1,2,3,4]
while a:
    print (a.pop()) #마지막 요소를 돌려주고 그 요소 삭제
# Out:
# 4
# 3
# 2
# 1

# %%
if[]:
    print('참')
else:
    print('거짓')
# Out:
# 거짓

# %%
if[1,2,3]:
    print('참')
else:
    print('거짓')
# Out:
# 참

# %%
bool('python')
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool([1,2,3])
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(3)
# Out:
# True

# %%
###################연습문제
k = 80
e = 75
m = 55
(k+e+m)/3
# Out:
# 70.0

# %%
13 % 2 #몫은 버리고 나머지만 취한다. 나머지가 0이면 짝수
# Out:
# 1

# %%
a = '881120-1068234'
yyyymmdd = a[:6]

# %%
yyyymmdd
# Out:
# '881120'

# %%
num = a[7:]

# %%
num
# Out:
# '1068234'

# %%
pin = '881120-1068234'
pin[7]
# Out:
# '1'

# %%
###################################################################
#if문

# %%
money = True
if money:
    print('택시를')
    print('타고')
    print('가라') #tap(들여쓰기)
# Out:
# 택시를
# 타고
# 가라

# %%
x = 3
y = 2
x > y
# Out:
# True

# %%
5 != 7 #같지 않다.
# Out:
# True

# %%
money = 2000
if money >= 3000:
    print('택시를 타고 가라')
else:
    print('걸어가라')
# Out:
# 걸어가라

# %%
money = 2000
card = True
if money >= 3000 or card:
    print('택시를 타고 가라')
else:
    print('걸어가라')
# Out:
# 택시를 타고 가라

# %%
money = 2000
card = True
if money >= 3000 and card:
    print('택시를 타고 가라')
else:
    print('걸어가라')
# Out:
# 걸어가라

# %%
1 in [1,2,3]
# Out:
# True

# %%
1 not in [1,2,3]
# Out:
# False

# %%
pocket = ['paper','cellphone','money']
if 'money' in pocket:
    print('택시를 타고 가라')
else:
    print('걸어가라')
# Out:
# 택시를 타고 가라

# %%
pocket = ['paper','handphone']
card = True
if 'money' in pocket:
    print('택시를 타고가라')
else:
    if card:
        print('택시를 타라')
    else:
        print('걸어가라')
# Out:
# 택시를 타라

# %%
pocket = ['paper','handphone']
card = True
if 'money' in pocket:
    print('택시를 타고가라')
elif card:
    print('택시를 타라')  #elif 개수 제한 없이 사용가능
else:
    print('걸어가라')
# Out:
# 택시를 타라

# %%
pocket = ['paper', 'money', 'cellphone']
if 'money' in pocket: pass
else: print("카드를 꺼내라")

# %%
##############################################
#while문 (while은 몇 번 반복시킬지 모를 때 사용, for문은 면 번 반복시킬 지 아는 경우)

# %%
treeHit = 0
while treeHit < 10:
    treeHit = treeHit +1
    print('나무를 %d번 찍었습니다.' %treeHit)
    if treeHit ==10:
        print('나무 넘어갑니다.')
# Out:
# 나무를 1번 찍었습니다.
# 나무를 2번 찍었습니다.
# 나무를 3번 찍었습니다.
# 나무를 4번 찍었습니다.
# 나무를 5번 찍었습니다.
# 나무를 6번 찍었습니다.
# 나무를 7번 찍었습니다.
# 나무를 8번 찍었습니다.
# 나무를 9번 찍었습니다.
# 나무를 10번 찍었습니다.
# 나무 넘어갑니다.

# %%
prompt = """
1. Add
2. Del
3. List
4. Quit
...
Enter number: """
number = 0
while number != 4:  #while은 몇 번 반복시킬지 모를 때 사용
    print(prompt)
    number = int(input()) #input은 string이다. 문자를 숫자로 바꿔준다.
# Out:
# 1. Add
# 2. Del
# 3. List
# 4. Quit
# ...
# Enter number:
# 1
#
# 1. Add
# 2. Del
# 3. List
# 4. Quit
# ...
# Enter number:
# 2
#
# 1. Add
# 2. Del
# 3. List
# 4. Quit
# ...
# Enter number:
# 3
#
# 1. Add
# 2. Del
# 3. List
# 4. Quit
# ...
# Enter number:
# 4

# %%
coffee = 10
money = 300
while money:
    print('돈을 받았으니 커피를 줍니다.')
    coffee = coffee -1 #하나씩 줄어든다.
    print('남은 커피의 양은 %d개 입니다.' %coffee)
    if coffee ==0:
        print('커피가 다 떨어졌습니다. 판매를 중지합니다.')
        break
# Out:
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 9개 입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 8개 입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 7개 입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 6개 입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 5개 입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 4개 입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 3개 입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 2개 입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 1개 입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 0개 입니다.
# 커피가 다 떨어졌습니다. 판매를 중지합니다.

# %%
coffee = 10
while True:
    money = int(input('돈을 넣어 주세요:'))
    if money == 300:
        print('커피를 줍니다.')
        coffee = coffee -1
    elif money > 300:
        print('거스름돈 %d를 주고 커피를 줍니다.' %(money -300))
        coffee = coffee -1
    else:
        print('돈을 다시 돌려주고 커피를 주지 않습니다.')
        print('남은 커피의 양은 %d개 입니다.' %coffee)
    if coffee == 0:
        print('커피가 다 떨어졌습니다. 판매를 중지합니다.')
        break
# Out:
# 돈을 넣어 주세요:300
# 커피를 줍니다.
# 돈을 넣어 주세요:400
# 거스름돈 100를 주고 커피를 줍니다.
# 돈을 넣어 주세요:200
# 돈을 다시 돌려주고 커피를 주지 않습니다.
# 남은 커피의 양은 8개 입니다.
# 돈을 넣어 주세요:300
# 커피를 줍니다.
# 돈을 넣어 주세요:350
# 거스름돈 50를 주고 커피를 줍니다.
# 돈을 넣어 주세요:400
# 거스름돈 100를 주고 커피를 줍니다.
# 돈을 넣어 주세요:600
# 거스름돈 300를 주고 커피를 줍니다.
# 돈을 넣어 주세요:300
# 커피를 줍니다.
# 돈을 넣어 주세요:300
# 커피를 줍니다.
# 돈을 넣어 주세요:300
# 커피를 줍니다.
# 돈을 넣어 주세요:300
# 커피를 줍니다.
# 커피가 다 떨어졌습니다. 판매를 중지합니다.

# %% [markdown]
# a = 0
# while a < 10:
#     a = a + 1
#     if a %2 ==0: contiue
#     print(a)

# %%
a = 0
while a < 10: 
    a = a + 1
    if a % 2 ==0: continue
    print(a)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
a = 0
while a < 10: 
    a = a + 2
    if a % 3 ==0: continue
    print(a)
# Out:
# 2
# 4
# 8
# 10

# %%
while True: #무한루프
    print("Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.")
# Out:
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다.
# ...

# %%
###############################################################
#for문

# %%
test_list = ['one','two','three']
for i in test_list:
    print(i)
# Out:
# one
# two
# three

# %%
a = [(1,2),(3,4),(5,6)]
for (first,last) in a:
    print(first + last)
# Out:
# 3
# 7
# 11
